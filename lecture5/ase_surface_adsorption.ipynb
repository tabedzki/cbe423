# %%
# !pip install quacc matcalc
# Out:
# Requirement already satisfied: quacc in c:\users\asros\miniconda3\envs\cms\lib\site-packages (1.1.2)
# Requirement already satisfied: matcalc in c:\users\asros\miniconda3\envs\cms\lib\site-packages (0.4.5)
# Requirement already satisfied: ase>=3.27.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from quacc) (3.27.0)
# Requirement already satisfied: custodian>=2025.12.14 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from quacc) (2025.12.14)
# Requirement already satisfied: emmet-core>=0.86.1 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from quacc) (0.86.2)
# Requirement already satisfied: frozendict>=2.4.6 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from quacc) (2.4.7)
# Requirement already satisfied: monty>=2024.5.15 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from quacc) (2025.3.3)
# Requirement already satisfied: numpy>=1.25.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from quacc) (2.4.0)
# Requirement already satisfied: psutil in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from quacc) (7.2.1)
# Requirement already satisfied: pydantic>=2.0.1 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from quacc) (2.12.5)
# Requirement already satisfied: pydantic-settings>=2.2.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from quacc) (2.12.0)
# Requirement already satisfied: pymatgen>=2024.10.22 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from quacc) (2025.10.7)
# Requirement already satisfied: ruamel.yaml>=0.17.40 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from quacc) (0.19.1)
# Requirement already satisfied: typer>=0.12.1 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from quacc) (0.21.0)
# Requirement already satisfied: scikit-learn>=1.6.1 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matcalc) (1.8.0)
# Requirement already satisfied: fsspec>=2025.3.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matcalc) (2025.12.0)
# Requirement already satisfied: joblib>=1.4.2 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matcalc) (1.5.3)
# Requirement already satisfied: phonopy>=2.38.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matcalc) (2.46.1)
# Requirement already satisfied: phono3py>=3.15.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matcalc) (3.22.0)
# Requirement already satisfied: scipy>=1.8.1 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from ase>=3.27.0->quacc) (1.16.3)
# Requirement already satisfied: matplotlib>=3.5.2 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from ase>=3.27.0->quacc) (3.10.8)
# Requirement already satisfied: pymatgen-io-validation>=0.1.1 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from emmet-core>=0.86.1->quacc) (0.1.2)
# Requirement already satisfied: pybtex~=0.24 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from emmet-core>=0.86.1->quacc) (0.25.1)
# Requirement already satisfied: typing-extensions>=3.7 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from emmet-core>=0.86.1->quacc) (4.15.0)
# Requirement already satisfied: blake3 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from emmet-core>=0.86.1->quacc) (1.0.8)
# Requirement already satisfied: PyYAML>=3.01 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pybtex~=0.24->emmet-core>=0.86.1->quacc) (6.0.3)
# Requirement already satisfied: latexcodec>=1.0.4 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pybtex~=0.24->emmet-core>=0.86.1->quacc) (3.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matplotlib>=3.5.2->ase>=3.27.0->quacc) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matplotlib>=3.5.2->ase>=3.27.0->quacc) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matplotlib>=3.5.2->ase>=3.27.0->quacc) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matplotlib>=3.5.2->ase>=3.27.0->quacc) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matplotlib>=3.5.2->ase>=3.27.0->quacc) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matplotlib>=3.5.2->ase>=3.27.0->quacc) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matplotlib>=3.5.2->ase>=3.27.0->quacc) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matplotlib>=3.5.2->ase>=3.27.0->quacc) (2.9.0.post0)
# Requirement already satisfied: h5py in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from phono3py>=3.15.0->matcalc) (3.15.1)
# Requirement already satisfied: spglib>=2.5.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from phono3py>=3.15.0->matcalc) (2.7.0)
# Requirement already satisfied: symfc>=1.5 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from phonopy>=2.38.0->matcalc) (1.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pydantic>=2.0.1->quacc) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pydantic>=2.0.1->quacc) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pydantic>=2.0.1->quacc) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pydantic-settings>=2.2.0->quacc) (1.2.1)
# Requirement already satisfied: bibtexparser>=1.4.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pymatgen>=2024.10.22->quacc) (1.4.3)
# Requirement already satisfied: networkx>=2.7 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pymatgen>=2024.10.22->quacc) (3.6.1)
# Requirement already satisfied: orjson<4,>=3.10 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pymatgen>=2024.10.22->quacc) (3.11.5)
# Requirement already satisfied: palettable>=3.3.3 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pymatgen>=2024.10.22->quacc) (3.3.3)
# Requirement already satisfied: pandas>=2 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pymatgen>=2024.10.22->quacc) (2.3.3)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pymatgen>=2024.10.22->quacc) (6.5.0)
# Requirement already satisfied: requests>=2.30 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pymatgen>=2024.10.22->quacc) (2.32.5)
# Requirement already satisfied: sympy>=1.3 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pymatgen>=2024.10.22->quacc) (1.14.0)
# Requirement already satisfied: tabulate>=0.9 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pymatgen>=2024.10.22->quacc) (0.9.0)
# Requirement already satisfied: tqdm>=4.60 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pymatgen>=2024.10.22->quacc) (4.67.1)
# Requirement already satisfied: uncertainties>=3.1.4 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pymatgen>=2024.10.22->quacc) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pandas>=2->pymatgen>=2024.10.22->quacc) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pandas>=2->pymatgen>=2024.10.22->quacc) (2025.3)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from plotly>=5.0.0->pymatgen>=2024.10.22->quacc) (2.14.0)
# Requirement already satisfied: six>=1.5 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.5.2->ase>=3.27.0->quacc) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from requests>=2.30->pymatgen>=2024.10.22->quacc) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from requests>=2.30->pymatgen>=2024.10.22->quacc) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from requests>=2.30->pymatgen>=2024.10.22->quacc) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from requests>=2.30->pymatgen>=2024.10.22->quacc) (2025.11.12)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from scikit-learn>=1.6.1->matcalc) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from sympy>=1.3->pymatgen>=2024.10.22->quacc) (1.3.0)
# Requirement already satisfied: colorama in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from tqdm>=4.60->pymatgen>=2024.10.22->quacc) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from typer>=0.12.1->quacc) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from typer>=0.12.1->quacc) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from typer>=0.12.1->quacc) (14.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from rich>=10.11.0->typer>=0.12.1->quacc) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from rich>=10.11.0->typer>=0.12.1->quacc) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.12.1->quacc) (0.1.2)

# %% [markdown]
# Here, we will demonstrate how to model surfaces. We will study the adsorption of N2 on Fe. For this analysis, we will use the TensorNet-MatPES-r2SCAN machine learning potential we used in a prior exercise. Again, the choice of calculator can be easily swapped and is not the main focal point of this exercise.
#
# The question we want to answer is: how strongly does N2 adsorb on the surface of iron, and what is the most stable adsorption geometry?

# %%
potential_name = "TensorNet-MatPES-r2SCAN-v2025.1-PES"

# %% [markdown]
# Our first order of business is to construct a surface of Fe. We start by taking the bulk structure of Fe and relaxing it. The bulk structure of Fe could be obtained from an experimental crystal structure, from the Materials Project, or any other place. We will take the one provideed by ASE for convenience.

# %%
from ase.build import bulk

crystal = bulk("Fe")

# %% [markdown]
# Now we attach the calculator and relax the bulk Fe structure. We make sure to relax both the positions and unit cell here.

# %%
from ase.filters import FrechetCellFilter
from ase.optimize import BFGS
from matcalc import load_fp

crystal.calc = load_fp(potential_name)  # Assign a calculator
crystal_wrapped = FrechetCellFilter(crystal)  # Tell ASE to optimize cell too
opt = BFGS(crystal_wrapped, trajectory="bulk_relax.traj")  # Set up optimizer
opt.run(fmax=0.01)  # Run optimization until forces < 0.01 eV/Å
# Out:
#       Step     Time          Energy          fmax
# BFGS:    0 21:23:56      -14.402250        0.111271
# BFGS:    1 21:23:56      -14.402630        0.047494
# BFGS:    2 21:23:56      -14.402715        0.000793
# np.True_

# %% [markdown]
# Now that we have a relaxed bulk structure, we can carve a surface. There are many tools to carve surfaces in Pymatgen, but I have already coded some convenient utilities in my code quacc. We will use those for simplicity. As always, we should look at the arguments and docstrings to understand what the function does.

# %%
from quacc.atoms.slabs import make_slabs_from_bulk

slabs = make_slabs_from_bulk(crystal)

# %% [markdown]
# We have generated a bunch of plausible surface slabs. Let's view some of them. Notice how some of the bottom layers are held fixed. If you wanted to do this yourself, you could do so with `ase.constraints.FixAtoms`.

# %%
from ase.visualize import view

view(slabs)
# Out:
# <Popen: returncode: None args: ['c:\\Users\\asros\\miniconda3\\envs\\cms\\py...>

# %% [markdown]
# Now that we have a bunch of surface slabs, which do we pick?
#
# We generally must find the one with the lowest energy. So, now we must relax each surface _at a fixed cell volume_ and find the one with the lowest energy.
#
# Technically, we should identify the surface with the lowest surface energy rather than total energy, but for simplicity we will ignore that since it will not change our approach.
#
# Remember that we cannot compare energies if the compositions are different, so we will have to normalize by the number of atoms.

# %%
for slab in slabs:
    slab.calc = load_fp(potential_name)
    opt = BFGS(slab)
    opt.run(fmax=0.01)
# Out:
# INFO:c:\Users\asros\miniconda3\envs\cms\Lib\site-packages\matgl\utils\io.py:Using cached local file at C:\Users\asros\.cache\matgl\TensorNet-MatPES-r2SCAN-v2025.1-PES\model.pt...
# INFO:c:\Users\asros\miniconda3\envs\cms\Lib\site-packages\matgl\utils\io.py:Using cached local file at C:\Users\asros\.cache\matgl\TensorNet-MatPES-r2SCAN-v2025.1-PES\state.pt...
# INFO:c:\Users\asros\miniconda3\envs\cms\Lib\site-packages\matgl\utils\io.py:Using cached local file at C:\Users\asros\.cache\matgl\TensorNet-MatPES-r2SCAN-v2025.1-PES\model.json...
#       Step     Time          Energy          fmax
# BFGS:    0 21:23:58     -728.335999        0.744082
# BFGS:    1 21:23:59     -728.385742        0.696431
# BFGS:    2 21:23:59     -728.637390        0.185446
# BFGS:    3 21:23:59     -728.640808        0.117617
# BFGS:    4 21:23:59     -728.642700        0.094741
# BFGS:    5 21:24:00     -728.650391        0.053678
# BFGS:    6 21:24:00     -728.651489        0.015681
# BFGS:    7 21:24:00     -728.651611        0.012194
# BFGS:    8 21:24:01     -728.651672        0.010710
# INFO:c:\Users\asros\miniconda3\envs\cms\Lib\site-packages\matgl\utils\io.py:Using cached local file at C:\Users\asros\.cache\matgl\TensorNet-MatPES-r2SCAN-v2025.1-PES\model.pt...
# INFO:c:\Users\asros\miniconda3\envs\cms\Lib\site-packages\matgl\utils\io.py:Using cached local file at C:\Users\asros\.cache\matgl\TensorNet-MatPES-r2SCAN-v2025.1-PES\state.pt...
# INFO:c:\Users\asros\miniconda3\envs\cms\Lib\site-packages\matgl\utils\io.py:Using cached local file at C:\Users\asros\.cache\matgl\TensorNet-MatPES-r2SCAN-v2025.1-PES\model.json...
# BFGS:    9 21:24:01     -728.651672        0.004956
#       Step     Time          Energy          fmax
# BFGS:    0 21:24:02    -1008.786133        0.576584
# BFGS:    1 21:24:02    -1008.836426        0.532177
# BFGS:    2 21:24:02    -1009.072021        0.172038
# BFGS:    3 21:24:03    -1009.077759        0.146461
# BFGS:    4 21:24:03    -1009.101562        0.116937
# BFGS:    5 21:24:03    -1009.113770        0.070169
# BFGS:    6 21:24:04    -1009.117798        0.062186
# BFGS:    7 21:24:04    -1009.118774        0.058084
# BFGS:    8 21:24:05    -1009.120728        0.068616
# BFGS:    9 21:24:05    -1009.123779        0.071683
# BFGS:   10 21:24:05    -1009.127869        0.052392
# BFGS:   11 21:24:06    -1009.130493        0.050126
# BFGS:   12 21:24:06    -1009.131226        0.040793
# BFGS:   13 21:24:06    -1009.131592        0.034786
# BFGS:   14 21:24:07    -1009.132141        0.029125
# BFGS:   15 21:24:07    -1009.132935        0.028413
# BFGS:   16 21:24:07    -1009.133850        0.020508
# BFGS:   17 21:24:08    -1009.134338        0.010197
# INFO:c:\Users\asros\miniconda3\envs\cms\Lib\site-packages\matgl\utils\io.py:Using cached local file at C:\Users\asros\.cache\matgl\TensorNet-MatPES-r2SCAN-v2025.1-PES\model.pt...
# INFO:c:\Users\asros\miniconda3\envs\cms\Lib\site-packages\matgl\utils\io.py:Using cached local file at C:\Users\asros\.cache\matgl\TensorNet-MatPES-r2SCAN-v2025.1-PES\state.pt...
# INFO:c:\Users\asros\miniconda3\envs\cms\Lib\site-packages\matgl\utils\io.py:Using cached local file at C:\Users\asros\.cache\matgl\TensorNet-MatPES-r2SCAN-v2025.1-PES\model.json...
# BFGS:   18 21:24:08    -1009.134399        0.002138
#       Step     Time          Energy          fmax
# BFGS:    0 21:24:08     -587.966553        0.397252
# BFGS:    1 21:24:08     -587.982422        0.335106
# INFO:c:\Users\asros\miniconda3\envs\cms\Lib\site-packages\matgl\utils\io.py:Using cached local file at C:\Users\asros\.cache\matgl\TensorNet-MatPES-r2SCAN-v2025.1-PES\model.pt...
# INFO:c:\Users\asros\miniconda3\envs\cms\Lib\site-packages\matgl\utils\io.py:Using cached local file at C:\Users\asros\.cache\matgl\TensorNet-MatPES-r2SCAN-v2025.1-PES\state.pt...
# INFO:c:\Users\asros\miniconda3\envs\cms\Lib\site-packages\matgl\utils\io.py:Using cached local file at C:\Users\asros\.cache\matgl\TensorNet-MatPES-r2SCAN-v2025.1-PES\model.json...
# BFGS:    2 21:24:09     -588.021362        0.011880
# BFGS:    3 21:24:09     -588.021362        0.004796
#       Step     Time          Energy          fmax
# BFGS:    0 21:24:09    -1123.056030        0.113668
# BFGS:    1 21:24:10    -1123.058838        0.105529
# BFGS:    2 21:24:10    -1123.076050        0.004755

# %%
for i, slab in enumerate(slabs):
    e = slab.get_potential_energy() / len(slab)
    print(f"Slab {i} energy: {e} eV/atom")
# Out:
# Slab 0 energy: -14.012532160832333 eV/atom
# Slab 1 energy: -14.015755547417534 eV/atom
# Slab 2 energy: -14.000508626302084 eV/atom
# Slab 3 energy: -14.038450622558594 eV/atom

# %% [markdown]
# We will continue with the lowest energy surface here.

# %%
import numpy as np

min_energy_index = np.argmin([slab.get_potential_energy() for slab in slabs])
slab = slabs[min_energy_index]

# %% [markdown]
# Now we need to add an adsorbate to our slab. Let's start by defining the N2 molecule.

# %%
from ase.build import molecule
from ase.optimize import BFGS

adsorbate = molecule("N2")
adsorbate.calc = load_fp(potential_name)
opt = BFGS(adsorbate)
opt.run(fmax=0.01)
# Out:
# INFO:c:\Users\asros\miniconda3\envs\cms\Lib\site-packages\matgl\utils\io.py:Using cached local file at C:\Users\asros\.cache\matgl\TensorNet-MatPES-r2SCAN-v2025.1-PES\model.pt...
# INFO:c:\Users\asros\miniconda3\envs\cms\Lib\site-packages\matgl\utils\io.py:Using cached local file at C:\Users\asros\.cache\matgl\TensorNet-MatPES-r2SCAN-v2025.1-PES\state.pt...
# INFO:c:\Users\asros\miniconda3\envs\cms\Lib\site-packages\matgl\utils\io.py:Using cached local file at C:\Users\asros\.cache\matgl\TensorNet-MatPES-r2SCAN-v2025.1-PES\model.json...
#       Step     Time          Energy          fmax
# BFGS:    0 21:24:10      -17.851177        3.448449
# BFGS:    1 21:24:11      -17.394592       14.897353
# BFGS:    2 21:24:11      -17.892418        0.943796
# BFGS:    3 21:24:11      -17.895245        0.237782
# BFGS:    4 21:24:11      -17.895433        0.005883
# np.True_

# %% [markdown]
# Now we need to add our adsorbate to our surface. There are many possible surface sites. The only way to know where the adsorbate should go is to add the adsorbate to all plausible surface sites, do a structure relaxation, and identify the lowest energy configuration(s). There are tools in Pymatgen to do this, but again we will use a utility function I have developed in quacc.

# %%
from quacc.atoms.slabs import make_adsorbate_structures

slab_adsorbates = make_adsorbate_structures(slab, adsorbate)

# %% [markdown]
# We now have many slab-adsorbate systems with the adsorbate at various sites.

# %%
view(slab_adsorbates)
# Out:
# <Popen: returncode: None args: ['c:\\Users\\asros\\miniconda3\\envs\\cms\\py...>

# %% [markdown]
# Time to relax each one to find the lowest energy configuration for the adsorbate. We do not need to normalize on a per-atom basis here because all the systems have the same number of atoms since we are using the same surface for each calculation.

# %%
from ase.optimize import BFGS

for slab_adsorbate in slab_adsorbates:
    slab_adsorbate.calc = load_fp(potential_name)
    opt = BFGS(slab_adsorbate)
    opt.run(fmax=0.01)
# Out:
# INFO:c:\Users\asros\miniconda3\envs\cms\Lib\site-packages\matgl\utils\io.py:Using cached local file at C:\Users\asros\.cache\matgl\TensorNet-MatPES-r2SCAN-v2025.1-PES\model.pt...
# INFO:c:\Users\asros\miniconda3\envs\cms\Lib\site-packages\matgl\utils\io.py:Using cached local file at C:\Users\asros\.cache\matgl\TensorNet-MatPES-r2SCAN-v2025.1-PES\state.pt...
# INFO:c:\Users\asros\miniconda3\envs\cms\Lib\site-packages\matgl\utils\io.py:Using cached local file at C:\Users\asros\.cache\matgl\TensorNet-MatPES-r2SCAN-v2025.1-PES\model.json...
#       Step     Time          Energy          fmax
# BFGS:    0 21:24:12    -1141.104980        2.813444
# BFGS:    1 21:24:13    -1141.014648        4.891023
# BFGS:    2 21:24:13    -1141.159424        0.797703
# BFGS:    3 21:24:14    -1141.177124        0.641555
# BFGS:    4 21:24:14    -1141.200928        0.922816
# BFGS:    5 21:24:15    -1141.218994        0.657942
# BFGS:    6 21:24:15    -1141.221069        0.242027
# BFGS:    7 21:24:15    -1141.222290        0.263479
# BFGS:    8 21:24:16    -1141.223755        0.428557
# BFGS:    9 21:24:16    -1141.225952        0.456410
# BFGS:   10 21:24:16    -1141.227173        0.269817
# BFGS:   11 21:24:17    -1141.227905        0.048570
# BFGS:   12 21:24:17    -1141.228394        0.174394
# BFGS:   13 21:24:18    -1141.229248        0.288200
# BFGS:   14 21:24:18    -1141.229980        0.264584
# BFGS:   15 21:24:18    -1141.230469        0.113906
# BFGS:   16 21:24:19    -1141.230591        0.032681
# BFGS:   17 21:24:19    -1141.230713        0.055946
# BFGS:   18 21:24:20    -1141.230713        0.062376
# BFGS:   19 21:24:20    -1141.230713        0.030237
# INFO:c:\Users\asros\miniconda3\envs\cms\Lib\site-packages\matgl\utils\io.py:Using cached local file at C:\Users\asros\.cache\matgl\TensorNet-MatPES-r2SCAN-v2025.1-PES\model.pt...
# INFO:c:\Users\asros\miniconda3\envs\cms\Lib\site-packages\matgl\utils\io.py:Using cached local file at C:\Users\asros\.cache\matgl\TensorNet-MatPES-r2SCAN-v2025.1-PES\state.pt...
# INFO:c:\Users\asros\miniconda3\envs\cms\Lib\site-packages\matgl\utils\io.py:Using cached local file at C:\Users\asros\.cache\matgl\TensorNet-MatPES-r2SCAN-v2025.1-PES\model.json...
# BFGS:   20 21:24:21    -1141.230713        0.004345
#       Step     Time          Energy          fmax
# BFGS:    0 21:24:22    -1140.879028        3.040851
# BFGS:    1 21:24:22    -1140.786499        4.962250
# BFGS:    2 21:24:23    -1140.931519        1.050057
# BFGS:    3 21:24:24    -1140.947998        0.565484
# BFGS:    4 21:24:25    -1140.968140        1.002244
# BFGS:    5 21:24:25    -1140.999268        0.863521
# BFGS:    6 21:24:26    -1141.003418        0.401521
# BFGS:    7 21:24:26    -1141.006104        0.292567
# BFGS:    8 21:24:27    -1141.009399        0.582148
# BFGS:    9 21:24:28    -1141.014771        0.789636
# BFGS:   10 21:24:28    -1141.019775        0.677056
# BFGS:   11 21:24:29    -1141.023315        0.330137
# BFGS:   12 21:24:29    -1141.025879        0.174100
# BFGS:   13 21:24:30    -1141.027832        0.378750
# BFGS:   14 21:24:30    -1141.030884        0.481097
# BFGS:   15 21:24:31    -1141.033081        0.318842
# BFGS:   16 21:24:31    -1141.034058        0.078411
# BFGS:   17 21:24:32    -1141.034424        0.075604
# BFGS:   18 21:24:32    -1141.034790        0.132404
# BFGS:   19 21:24:32    -1141.035034        0.107346
# BFGS:   20 21:24:33    -1141.035156        0.037711
# BFGS:   21 21:24:33    -1141.035156        0.014073
# BFGS:   22 21:24:34    -1141.035156        0.037728
# BFGS:   23 21:24:34    -1141.035156        0.052001
# BFGS:   24 21:24:35    -1141.035278        0.038970
# BFGS:   25 21:24:35    -1141.035278        0.011888
# INFO:c:\Users\asros\miniconda3\envs\cms\Lib\site-packages\matgl\utils\io.py:Using cached local file at C:\Users\asros\.cache\matgl\TensorNet-MatPES-r2SCAN-v2025.1-PES\model.pt...
# INFO:c:\Users\asros\miniconda3\envs\cms\Lib\site-packages\matgl\utils\io.py:Using cached local file at C:\Users\asros\.cache\matgl\TensorNet-MatPES-r2SCAN-v2025.1-PES\state.pt...
# INFO:c:\Users\asros\miniconda3\envs\cms\Lib\site-packages\matgl\utils\io.py:Using cached local file at C:\Users\asros\.cache\matgl\TensorNet-MatPES-r2SCAN-v2025.1-PES\model.json...
# BFGS:   26 21:24:35    -1141.035278        0.008923
#       Step     Time          Energy          fmax
# BFGS:    0 21:24:36    -1140.630859        2.931492
# BFGS:    1 21:24:36    -1140.531860        4.932026
# BFGS:    2 21:24:37    -1140.679443        0.928404
# BFGS:    3 21:24:37    -1140.692871        0.439800
# BFGS:    4 21:24:37    -1140.707886        0.780145
# BFGS:    5 21:24:38    -1140.735352        0.654863
# BFGS:    6 21:24:38    -1140.738892        0.268889
# BFGS:    7 21:24:39    -1140.741211        0.248275
# BFGS:    8 21:24:39    -1140.744629        0.522101
# BFGS:    9 21:24:39    -1140.748901        0.619986
# BFGS:   10 21:24:40    -1140.752808        0.451529
# BFGS:   11 21:24:40    -1140.755981        0.149325
# BFGS:   12 21:24:41    -1140.759033        0.369569
# BFGS:   13 21:24:41    -1140.763550        0.644333
# BFGS:   14 21:24:42    -1140.769043        0.729455
# BFGS:   15 21:24:42    -1140.773804        0.507672
# BFGS:   16 21:24:42    -1140.778564        0.130714
# BFGS:   17 21:24:43    -1140.782959        0.456280
# BFGS:   18 21:24:43    -1140.788452        0.723292
# BFGS:   19 21:24:44    -1140.793213        0.674620
# BFGS:   20 21:24:44    -1140.797119        0.388531
# BFGS:   21 21:24:45    -1140.799194        0.121960
# BFGS:   22 21:24:45    -1140.800903        0.352268
# BFGS:   23 21:24:46    -1140.802856        0.380129
# BFGS:   24 21:24:46    -1140.807373        0.246380
# BFGS:   25 21:24:46    -1140.808594        0.107527
# BFGS:   26 21:24:47    -1140.809204        0.042550
# BFGS:   27 21:24:47    -1140.809448        0.053275
# BFGS:   28 21:24:48    -1140.809814        0.075972
# BFGS:   29 21:24:48    -1140.810059        0.055934
# BFGS:   30 21:24:49    -1140.810181        0.017232
# INFO:c:\Users\asros\miniconda3\envs\cms\Lib\site-packages\matgl\utils\io.py:Using cached local file at C:\Users\asros\.cache\matgl\TensorNet-MatPES-r2SCAN-v2025.1-PES\model.pt...
# INFO:c:\Users\asros\miniconda3\envs\cms\Lib\site-packages\matgl\utils\io.py:Using cached local file at C:\Users\asros\.cache\matgl\TensorNet-MatPES-r2SCAN-v2025.1-PES\state.pt...
# INFO:c:\Users\asros\miniconda3\envs\cms\Lib\site-packages\matgl\utils\io.py:Using cached local file at C:\Users\asros\.cache\matgl\TensorNet-MatPES-r2SCAN-v2025.1-PES\model.json...
# BFGS:   31 21:24:49    -1140.810181        0.006292
#       Step     Time          Energy          fmax
# BFGS:    0 21:24:50    -1140.757812        3.058002
# BFGS:    1 21:24:50    -1140.658936        4.989618
# BFGS:    2 21:24:50    -1140.806396        1.007305
# BFGS:    3 21:24:51    -1140.819946        0.616288
# BFGS:    4 21:24:51    -1140.836670        0.977635
# BFGS:    5 21:24:52    -1140.881348        0.962821
# BFGS:    6 21:24:52    -1140.892212        0.511483
# BFGS:    7 21:24:52    -1140.903198        0.582371
# BFGS:    8 21:24:53    -1140.926270        1.708068
# BFGS:    9 21:24:53    -1140.953369        2.130585
# BFGS:   10 21:24:54    -1141.008789        1.889343
# BFGS:   11 21:24:54    -1141.030640        0.965714
# BFGS:   12 21:24:54    -1141.055054        0.655430
# BFGS:   13 21:24:55    -1141.065796        1.429600
# BFGS:   14 21:24:55    -1141.083130        0.700658
# BFGS:   15 21:24:56    -1141.099121        0.948826
# BFGS:   16 21:24:56    -1141.104858        0.146109
# BFGS:   17 21:24:56    -1141.106201        0.136615
# BFGS:   18 21:24:57    -1141.109985        0.227407
# BFGS:   19 21:24:57    -1141.112061        0.277415
# BFGS:   20 21:24:58    -1141.114990        0.284664
# BFGS:   21 21:24:58    -1141.117310        0.228410
# BFGS:   22 21:24:58    -1141.121094        0.171825
# BFGS:   23 21:24:59    -1141.126831        0.254325
# BFGS:   24 21:24:59    -1141.136230        0.386436
# BFGS:   25 21:25:00    -1141.146851        0.296721
# BFGS:   26 21:25:00    -1141.153564        0.163886
# BFGS:   27 21:25:01    -1141.157227        0.240087
# BFGS:   28 21:25:01    -1141.162964        0.313053
# BFGS:   29 21:25:01    -1141.171387        0.220797
# BFGS:   30 21:25:02    -1141.178711        0.242880
# BFGS:   31 21:25:02    -1141.184448        0.276913
# BFGS:   32 21:25:03    -1141.190308        0.254755
# BFGS:   33 21:25:03    -1141.197021        0.184652
# BFGS:   34 21:25:03    -1141.204956        0.956287
# BFGS:   35 21:25:04    -1141.212646        0.651663
# BFGS:   36 21:25:04    -1141.219604        0.139180
# BFGS:   37 21:25:05    -1141.222290        0.101983
# BFGS:   38 21:25:05    -1141.224365        0.142141
# BFGS:   39 21:25:06    -1141.226685        0.078843
# BFGS:   40 21:25:06    -1141.228271        0.049725
# BFGS:   41 21:25:06    -1141.228760        0.054424
# BFGS:   42 21:25:07    -1141.229004        0.033239
# BFGS:   43 21:25:07    -1141.229248        0.040005
# BFGS:   44 21:25:08    -1141.229492        0.041525
# BFGS:   45 21:25:08    -1141.229736        0.032482
# BFGS:   46 21:25:09    -1141.229858        0.033043
# BFGS:   47 21:25:10    -1141.230103        0.031949
# BFGS:   48 21:25:10    -1141.230225        0.028592
# BFGS:   49 21:25:10    -1141.230469        0.028131
# BFGS:   50 21:25:11    -1141.230591        0.016015
# BFGS:   51 21:25:11    -1141.230591        0.014248
# BFGS:   52 21:25:12    -1141.230591        0.012230
# BFGS:   53 21:25:12    -1141.230713        0.012968
# BFGS:   54 21:25:13    -1141.230713        0.012859
# BFGS:   55 21:25:14    -1141.230713        0.010243
# BFGS:   56 21:25:14    -1141.230713        0.008270

# %%
for i, slab_adsorbate in enumerate(slab_adsorbates):
    print(f"System {i} energy: {slab_adsorbate.get_potential_energy()} eV")
# Out:
# System 0 energy: -1141.230712890625 eV
# System 1 energy: -1141.0352783203125 eV
# System 2 energy: -1140.8101806640625 eV
# System 3 energy: -1141.230712890625 eV

# %%
view(slab_adsorbates)
# Out:
# <Popen: returncode: None args: ['c:\\Users\\asros\\miniconda3\\envs\\cms\\py...>

# %% [markdown]
# We will continue with the lowest energy configuration.

# %%
min_idx = np.argmin(
    [slab_adsorbate.get_potential_energy() for slab_adsorbate in slab_adsorbates]
)
final_system = slab_adsorbates[min_idx]

# %%
view(final_system)
# Out:
# <Popen: returncode: None args: ['c:\\Users\\asros\\miniconda3\\envs\\cms\\py...>

# %% [markdown]
# We can be thorough and confirm that the structure we have is indeed a local minimum by carrying out a vibrational mode analysis.

# %%
from ase.vibrations import Vibrations

vib = Vibrations(final_system)
vib.run()
vib.summary()
# Out:
# ---------------------
#   #    meV     cm^-1
# ---------------------
#   0    6.0      48.3
#   1    6.7      53.9
#   2    7.8      63.0
#   3   11.3      91.0
#   4   11.3      91.1
#   5   11.4      92.1
#   6   11.5      92.6
#   7   11.6      93.3
#   8   12.7     102.1
#   9   13.4     108.4
#  10   14.2     114.9
#  11   19.7     159.0
#  12   19.7     159.1
#  13   19.9     160.2
#  14   19.9     160.4
#  15   19.9     160.5
#  16   19.9     160.6
#  17   19.9     160.8
#  18   20.0     160.9
#  19   20.0     161.6
#  20   20.2     162.7
#  21   20.4     164.3
#  22   20.7     166.8
#  23   20.7     166.9
#  24   20.9     168.6
#  25   21.1     170.4
#  26   21.1     170.5
#  27   21.3     172.1
#  28   21.9     176.5
#  29   22.5     181.7
#  30   23.0     185.9
#  31   23.1     186.3
#  32   23.2     186.8
#  33   23.2     186.9
#  34   23.4     189.0
#  35   23.5     189.4
#  36   23.6     190.3
#  37   24.0     193.3
#  38   24.1     194.1
#  39   25.0     201.6
#  40   25.7     207.2
#  41   25.8     208.1
#  42   26.3     212.1
#  43   29.1     235.1
#  44   29.3     236.2
#  45   29.7     239.8
#  46   30.3     244.3
#  47   30.5     246.3
#  48   30.8     248.1
#  49   32.2     260.0
#  50   33.1     267.2
#  51   33.5     270.4
#  52   33.6     271.4
#  53  253.2    2042.4
# ---------------------
# Zero-point energy: 0.693 eV

# %% [markdown]
# No imaginary modes. Excellent!

# %% [markdown]
# Now, we can calculate the adsorption energy.

# %%
delta_E = (
    final_system.get_potential_energy()
    - slab.get_potential_energy()
    - adsorbate.get_potential_energy()
)
print(f"Adsorption energy: {delta_E} eV")
# Out:
# Adsorption energy: -0.2592296600341797 eV
