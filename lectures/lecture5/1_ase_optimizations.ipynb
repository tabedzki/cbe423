# %% [markdown]
# # Overview
#
# Here, we will demonstrate how to carry out geometry optimizations using ASE. For this, we need to pick an energy model --- which in ASE is called a calculator. The calculator is the simulation engine that, given an atomic configuration, will return the energy of the system (as well as forces and, for solids, the unit cell stresses).
#
# For this exercise, we will mainly use a "machine learning potential". We will cover machine learning potentials in greater detail later in the course, but it is a machine learning model trained to reproduce density functional theory energy, forces, and stresses at a low computational cost. The model we will use in this exercise is called TensorNet-MatPES-r2SCAN from https://arxiv.org/abs/2503.04070.

# %% [markdown]
# # Setup

# %% [markdown]
# There is a bug with the ASE GUI in ase 3.27.0, so until 3.27.1 is released, we will install the development version.

# %%
# %uv pip install ase@git+https://gitlab.com/ase/ase.git
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Using Python 3.13.11 environment at: C:\Users\asros\miniconda3\envs\cms
#    Updating https://gitlab.com/ase/ase.git (HEAD)
#     Updated https://gitlab.com/ase/ase.git (9e022fa5b8d123bc1785145661104a4f893a10c0)
# Resolved 13 packages in 11.27s
# Audited 13 packages in 5ms

# %% [markdown]
# For this demonstration, we also need to install a code called matcalc. This will give us the machine learning potential to use as our energy and force calculator.

# %%
# %uv pip install matcalc[matgl]
# Out:
# Requirement already satisfied: matcalc[matgl] in c:\users\asros\miniconda3\envs\cms\lib\site-packages (0.4.5)
# Requirement already satisfied: ase>=3.26.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matcalc[matgl]) (3.27.0)
# Requirement already satisfied: scikit-learn>=1.6.1 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matcalc[matgl]) (1.8.0)
# Requirement already satisfied: pymatgen>=2025.4.20 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matcalc[matgl]) (2025.10.7)
# Requirement already satisfied: fsspec>=2025.3.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matcalc[matgl]) (2026.1.0)
# Requirement already satisfied: joblib>=1.4.2 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matcalc[matgl]) (1.5.3)
# Requirement already satisfied: phonopy>=2.38.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matcalc[matgl]) (2.47.1)
# Requirement already satisfied: phono3py>=3.15.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matcalc[matgl]) (3.24.0)
# Requirement already satisfied: matgl>=2.0.2 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matcalc[matgl]) (2.0.6)
# Requirement already satisfied: numpy>=1.21.6 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from ase>=3.26.0->matcalc[matgl]) (2.3.5)
# Requirement already satisfied: scipy>=1.8.1 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from ase>=3.26.0->matcalc[matgl]) (1.17.0)
# Requirement already satisfied: matplotlib>=3.5.2 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from ase>=3.26.0->matcalc[matgl]) (3.10.8)
# Requirement already satisfied: torch<=2.8.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matgl>=2.0.2->matcalc[matgl]) (2.8.0)
# Requirement already satisfied: torchdata in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matgl>=2.0.2->matcalc[matgl]) (0.11.0)
# Requirement already satisfied: lightning<=2.6.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matgl>=2.0.2->matcalc[matgl]) (2.6.0)
# Requirement already satisfied: pydantic in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matgl>=2.0.2->matcalc[matgl]) (2.12.5)
# Requirement already satisfied: boto3 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matgl>=2.0.2->matcalc[matgl]) (1.42.30)
# Requirement already satisfied: torch-geometric in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matgl>=2.0.2->matcalc[matgl]) (2.7.0)
# Requirement already satisfied: PyYAML<8.0,>5.4 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from lightning<=2.6.0->matgl>=2.0.2->matcalc[matgl]) (6.0.3)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from lightning<=2.6.0->matgl>=2.0.2->matcalc[matgl]) (0.15.2)
# Requirement already satisfied: packaging<27.0,>=20.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from lightning<=2.6.0->matgl>=2.0.2->matcalc[matgl]) (25.0)
# Requirement already satisfied: torchmetrics<3.0,>0.7.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from lightning<=2.6.0->matgl>=2.0.2->matcalc[matgl]) (1.8.2)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from lightning<=2.6.0->matgl>=2.0.2->matcalc[matgl]) (4.67.1)
# Requirement already satisfied: typing-extensions<6.0,>4.5.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from lightning<=2.6.0->matgl>=2.0.2->matcalc[matgl]) (4.15.0)
# Requirement already satisfied: pytorch-lightning in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from lightning<=2.6.0->matgl>=2.0.2->matcalc[matgl]) (2.6.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning<=2.6.0->matgl>=2.0.2->matcalc[matgl]) (3.13.3)
# Requirement already satisfied: setuptools in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from lightning-utilities<2.0,>=0.10.0->lightning<=2.6.0->matgl>=2.0.2->matcalc[matgl]) (80.9.0)
# Requirement already satisfied: filelock in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from torch<=2.8.0->matgl>=2.0.2->matcalc[matgl]) (3.20.3)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from torch<=2.8.0->matgl>=2.0.2->matcalc[matgl]) (1.14.0)
# Requirement already satisfied: networkx in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from torch<=2.8.0->matgl>=2.0.2->matcalc[matgl]) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from torch<=2.8.0->matgl>=2.0.2->matcalc[matgl]) (3.1.6)
# Requirement already satisfied: colorama in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from tqdm<6.0,>=4.57.0->lightning<=2.6.0->matgl>=2.0.2->matcalc[matgl]) (0.4.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<=2.6.0->matgl>=2.0.2->matcalc[matgl]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<=2.6.0->matgl>=2.0.2->matcalc[matgl]) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<=2.6.0->matgl>=2.0.2->matcalc[matgl]) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<=2.6.0->matgl>=2.0.2->matcalc[matgl]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<=2.6.0->matgl>=2.0.2->matcalc[matgl]) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<=2.6.0->matgl>=2.0.2->matcalc[matgl]) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<=2.6.0->matgl>=2.0.2->matcalc[matgl]) (1.22.0)
# Requirement already satisfied: idna>=2.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<=2.6.0->matgl>=2.0.2->matcalc[matgl]) (3.11)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matplotlib>=3.5.2->ase>=3.26.0->matcalc[matgl]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matplotlib>=3.5.2->ase>=3.26.0->matcalc[matgl]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matplotlib>=3.5.2->ase>=3.26.0->matcalc[matgl]) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matplotlib>=3.5.2->ase>=3.26.0->matcalc[matgl]) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matplotlib>=3.5.2->ase>=3.26.0->matcalc[matgl]) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matplotlib>=3.5.2->ase>=3.26.0->matcalc[matgl]) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from matplotlib>=3.5.2->ase>=3.26.0->matcalc[matgl]) (2.9.0.post0)
# Requirement already satisfied: h5py in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from phono3py>=3.15.0->matcalc[matgl]) (3.15.1)
# Requirement already satisfied: spglib>=2.5.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from phono3py>=3.15.0->matcalc[matgl]) (2.7.0)
# Requirement already satisfied: symfc>=1.5 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from phonopy>=2.38.0->matcalc[matgl]) (1.6.0)
# Requirement already satisfied: bibtexparser>=1.4.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pymatgen>=2025.4.20->matcalc[matgl]) (1.4.3)
# Requirement already satisfied: monty>=2025.1.9 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pymatgen>=2025.4.20->matcalc[matgl]) (2025.3.3)
# Requirement already satisfied: orjson<4,>=3.10 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pymatgen>=2025.4.20->matcalc[matgl]) (3.11.5)
# Requirement already satisfied: palettable>=3.3.3 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pymatgen>=2025.4.20->matcalc[matgl]) (3.3.3)
# Requirement already satisfied: pandas>=2 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pymatgen>=2025.4.20->matcalc[matgl]) (2.3.3)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pymatgen>=2025.4.20->matcalc[matgl]) (6.5.2)
# Requirement already satisfied: requests>=2.30 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pymatgen>=2025.4.20->matcalc[matgl]) (2.32.5)
# Requirement already satisfied: ruamel.yaml>=0.17.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pymatgen>=2025.4.20->matcalc[matgl]) (0.19.1)
# Requirement already satisfied: tabulate>=0.9 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pymatgen>=2025.4.20->matcalc[matgl]) (0.9.0)
# Requirement already satisfied: uncertainties>=3.1.4 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pymatgen>=2025.4.20->matcalc[matgl]) (3.2.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pandas>=2->pymatgen>=2025.4.20->matcalc[matgl]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pandas>=2->pymatgen>=2025.4.20->matcalc[matgl]) (2025.3)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from plotly>=5.0.0->pymatgen>=2025.4.20->matcalc[matgl]) (2.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.5.2->ase>=3.26.0->matcalc[matgl]) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from requests>=2.30->pymatgen>=2025.4.20->matcalc[matgl]) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from requests>=2.30->pymatgen>=2025.4.20->matcalc[matgl]) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from requests>=2.30->pymatgen>=2025.4.20->matcalc[matgl]) (2026.1.4)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from scikit-learn>=1.6.1->matcalc[matgl]) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from sympy>=1.13.3->torch<=2.8.0->matgl>=2.0.2->matcalc[matgl]) (1.3.0)
# Requirement already satisfied: botocore<1.43.0,>=1.42.30 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from boto3->matgl>=2.0.2->matcalc[matgl]) (1.42.30)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from boto3->matgl>=2.0.2->matcalc[matgl]) (1.0.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from boto3->matgl>=2.0.2->matcalc[matgl]) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from jinja2->torch<=2.8.0->matgl>=2.0.2->matcalc[matgl]) (3.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pydantic->matgl>=2.0.2->matcalc[matgl]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pydantic->matgl>=2.0.2->matcalc[matgl]) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from pydantic->matgl>=2.0.2->matcalc[matgl]) (0.4.2)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from torch-geometric->matgl>=2.0.2->matcalc[matgl]) (7.2.1)
# Requirement already satisfied: xxhash in c:\users\asros\miniconda3\envs\cms\lib\site-packages (from torch-geometric->matgl>=2.0.2->matcalc[matgl]) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Demonstration

# %% [markdown]
# First, we will need to define our atomic system. We will study a porous material called a metal-organic framework, specifically MOF-5.

# %%
from ase.io import read

atoms = read("mof5.cif")

# %%
atoms
# Out:
# Atoms(symbols='C192H96O104Zn32', pbc=True, cell=[[25.880232683010675, 4.250589686636913e-08, 7.847959566961198e-08], [4.250537110201552e-08, 25.880232947121996, 1.6312256899758683e-08], [7.84792244170589e-08, 1.6328391036896475e-08, 25.880232785123376]], spacegroup_kinds=..., calculator=LennardJones(...))

# %%
from ase.visualize import view

view(atoms)
# Out:
# <Popen: returncode: None args: ['c:\\Users\\asros\\miniconda3\\envs\\cms\\py...>

# %% [markdown]
# Now we need to define a calculator. ASE comes with many pre-made calculators (https://ase-lib.org/ase/calculators/calculators.html), and there are many external codes that ship their own ASE calculators.

# %% [markdown]
# We will load the TensorNet-MatPES-r2SCAN calculator

# %%
from matcalc import load_fp

calc = load_fp("TensorNet-MatPES-r2SCAN-v2025.1-PES")

# %% [markdown]
# Now we can attach the calculator to the `Atoms` object.

# %%
atoms.calc = calc

# %% [markdown]
# We now have everything we need to run a calculation. Let's start with running a static (single-point) calculation.

# %%
e_initial = atoms.get_potential_energy()
print(e_initial)
# Out:
# -3339.190185546875

# %% [markdown]
# It is always important to understand the units of any given code. In the case of ASE, energies are given in eV (https://ase-lib.org/ase/units.html). There are 96.49 kJ/mol per eV.
#
# An energy on its own is meaningless. It must be referenced to something. We will come back to this.

# %% [markdown]
# The structure we loaded not be a minimum energy structure. We must run a geometry optimization to obtain this. We can do this in ASE as well.
#
# ASE comes with many optimizers. We will use BFGS.

# %%
from ase.optimize import BFGS

# Set up the BFGS optimizer and specify output file
opt = BFGS(atoms, trajectory="opt.traj")

# %%
opt.run(fmax=0.01)  # Run until the maximum force is less than 0.01 eV/Å
# Out:
#       Step     Time          Energy          fmax
# BFGS:    0 11:39:37    -3339.190186        0.343954
# BFGS:    1 11:39:39    -3339.353516        0.215392
# BFGS:    2 11:39:41    -3339.451660        0.134192
# BFGS:    3 11:39:43    -3339.477539        0.099507
# BFGS:    4 11:39:44    -3339.499756        0.062971
# BFGS:    5 11:39:46    -3339.511963        0.051177
# BFGS:    6 11:39:47    -3339.516113        0.017784
# BFGS:    7 11:39:48    -3339.516602        0.010649
# BFGS:    8 11:39:50    -3339.516602        0.009292
# np.True_

# %%
e_final = atoms.get_potential_energy()  # get the optimized energy
print(e_final - e_initial)  # print the energy difference
# Out:
# -0.326416015625

# %%
atoms.get_forces()
# Out:
# array([[-0.00248075, -0.00248073,  0.00248153],
#        [ 0.00248719,  0.0024947 , -0.00250016],
#        [ 0.00250266,  0.00249279,  0.00248121],
#        ...,
#        [-0.00409735,  0.00585589,  0.00585571],
#        [-0.00414147,  0.00580159, -0.00580242],
#        [ 0.00411937, -0.00582212,  0.0058229 ]],
#       shape=(424, 3), dtype=float32)

# %% [markdown]
# It looks like we found a lower energy structure. Let's take a look at the optimization trajectory now.

# %%
trajectory = read("opt.traj", index=":")  # index=":" means read all the frames

# %%
from ase.visualize import view

view(trajectory)
# Out:
# <Popen: returncode: None args: ['c:\\Users\\asros\\miniconda3\\envs\\cms\\py...>

# %% [markdown]
# If you look closely, you will see that the atomic positions updated and the energy went down. The forces went down too.
#
# But note that the unit cell shape and size did not change. In addition to the atomic positions, the unit cell can also be optimized. After all, if you made the unit cell too big, that may not be the lowest energy structure. We can optimize both the positions and unit cell in ASE simultaneously.
#
# In ASE, this is done by wrapping the `Atoms` object in a "Cell Filter". Otherwise, the procedure remains largely the same.

# %%
from ase.filters import FrechetCellFilter

# this tells ASE to optimize both atomic positions and cell parameters
fcf = FrechetCellFilter(atoms)

# %%
opt = BFGS(fcf, trajectory="opt2.traj")
opt.run(fmax=0.01)
# Out:
#       Step     Time          Energy          fmax
# BFGS:    0 11:39:51    -3339.516602        0.099594
# BFGS:    1 11:39:53    -3339.516846        0.099030
# BFGS:    2 11:39:55    -3339.522949        0.093084
# BFGS:    3 11:39:57    -3339.525879        0.090448
# BFGS:    4 11:39:58    -3339.532959        0.086335
# BFGS:    5 11:40:00    -3339.540771        0.085053
# BFGS:    6 11:40:01    -3339.551270        0.086359
# BFGS:    7 11:40:02    -3339.564941        0.089813
# BFGS:    8 11:40:04    -3339.586670        0.094768
# BFGS:    9 11:40:05    -3339.617432        0.098252
# BFGS:   10 11:40:07    -3339.650391        0.102750
# BFGS:   11 11:40:08    -3339.684570        0.110435
# BFGS:   12 11:40:10    -3339.718994        0.111838
# BFGS:   13 11:40:11    -3339.754395        0.109309
# BFGS:   14 11:40:12    -3339.788086        0.103902
# BFGS:   15 11:40:13    -3339.822510        0.096853
# BFGS:   16 11:40:15    -3339.855957        0.088642
# BFGS:   17 11:40:16    -3339.888672        0.079743
# BFGS:   18 11:40:17    -3339.919678        0.078459
# BFGS:   19 11:40:19    -3339.948730        0.076531
# BFGS:   20 11:40:20    -3339.974121        0.071036
# BFGS:   21 11:40:21    -3339.995850        0.061538
# BFGS:   22 11:40:23    -3340.012695        0.047886
# BFGS:   23 11:40:24    -3340.022949        0.028342
# BFGS:   24 11:40:25    -3340.024902        0.011999
# BFGS:   25 11:40:27    -3340.025146        0.007031
# np.True_

# %%
atoms.get_potential_energy()  # get the optimized energy
# Out:
# -3340.025146484375

# %%
view(read("opt2.traj", index=":"))
# Out:
# <Popen: returncode: None args: ['c:\\Users\\asros\\miniconda3\\envs\\cms\\py...>

# %% [markdown]
# Finally, we will note that there are many ASE calculators, some based on empirical potentials, some based on ML models, some based on quantum chemistry, and so on. An incomplete list can be found at https://ase-lib.org/ase/calculators/calculators.html. It is easy to swap to a different calculator and to do the same procedure as above.
#
# For instance, we could run a calculation with a Lennard-Jones potential in exactly the same way. Note: Of course, the LJ potential we have chosen here is completely unphysical.

# %%
from ase.calculators.lj import LennardJones

# %%
# We will run a toy single-point calculation with an LJ potential
# This is completely unphysical because we have arbitrarily chosen sigma=1.0 and epsilon=1.0
# But it serves to illustrate how to set up a different calculator and also how
# to specify keyword arguments

atoms.calc = LennardJones(sigma=1.0, epsilon=1.0)
atoms.get_potential_energy()
# Out:
# np.float64(-269.3023998243027)
